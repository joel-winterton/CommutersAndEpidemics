# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
large_alt_series = np.fromfile('alt_series.bin')

points_analysed = np.array([0, 0.01, 0.02, 0.04, 0.05, 0.1, 0.125, 0.25, 0.35, 0.45, 0.5])
samples = 50
patches = 50
points = len(points_analysed)
large_alt_series = large_alt_series.reshape((points,samples,patches))

# %%
targets = [3,-1]
site_numbers = np.arange(0, patches)
plt.plot(np.mean(large_alt_series[0], axis=0), site_numbers, label=f'$p_a = {points_analysed[0]}$', linewidth=0.8, linestyle='--', c='blue')
for target in targets:
    mean_peaks = np.mean(large_alt_series[target], axis=0)
    plt.plot(mean_peaks, site_numbers, label=f'$p_a = {points_analysed[target]}$', linewidth=0.8)
plt.xlabel('Mean peak time')
plt.ylabel('Site number')
plt.legend()
plt.show()
